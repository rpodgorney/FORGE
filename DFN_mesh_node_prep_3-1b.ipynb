# %%
import pandas as pd

# %%
data=pd.read_csv('large_well_3-1b_node.csv', skiprows = 10, float_precision='round_trip')

# %%
data.describe()
# Out:
#                  Id             X             Y             Z         dX  \
# count  3.996081e+06  3.996081e+06  3.996081e+06  3.996081e+06  3996081.0
# mean   1.998040e+06  7.500000e+02  1.120000e+03 -4.750000e+02       10.0
# std    1.153569e+06  4.070218e+02  4.070218e+02  5.802299e+02        0.0
# min    0.000000e+00  5.000000e+01  4.200000e+02 -1.475000e+03       10.0
# 25%    9.990200e+05  4.000000e+02  7.700000e+02 -9.750000e+02       10.0
# 50%    1.998040e+06  7.500000e+02  1.120000e+03 -4.750000e+02       10.0
# 75%    2.997060e+06  1.100000e+03  1.470000e+03  2.500000e+01       10.0
# max    3.996080e+06  1.450000e+03  1.820000e+03  5.250000e+02       10.0
#
#               dY         dZ  pressure_MPa  sigma_h_max_MPa  sigma_h_min_MPa  \
# count  3996081.0  3996081.0  3.996081e+06     3.996081e+06     3.996081e+06
# mean        10.0       10.0  1.902218e+01     3.699827e+01     3.217816e+01
# std          0.0        0.0  5.084631e+00     1.035117e+01     8.908026e+00
# min         10.0       10.0  1.002488e+01     1.864353e+01     1.617470e+01
# 25%         10.0       10.0  1.464307e+01     2.821518e+01     2.474237e+01
# 50%         10.0       10.0  1.912009e+01     3.710544e+01     3.241430e+01
# 75%         10.0       10.0  2.343801e+01     4.591633e+01     3.983032e+01
# max         10.0       10.0  2.766735e+01     5.518527e+01     4.743421e+01
#
#         Sigma_V_MPa  temperature_C
# count  3.996081e+06   3.996081e+06
# mean   5.277819e+01   1.833050e+02
# std    1.570728e+01   3.502214e+01
# min    2.544605e+01   1.106922e+02
# 25%    3.904700e+01   1.541820e+02
# 50%    5.275623e+01   1.842313e+02
# 75%    6.641029e+01   2.131155e+02
# max    8.065098e+01   2.555467e+02

# %% [markdown]
# All is good.  BUT...because the file is so big, it can't be edited in Excel, so need to add some additional columns to the file now, and then later add the 10 row header that is usually written by Leapfrog

# %% [markdown]
# Add the disp_k_bc	disp_j_bc	disp_i_bc	vertical	h_max	h_min columns

# %%
data.insert(loc=8, column='disp_k_bc', value=1)

# %%
data.insert(loc=9, column='disp_j_bc', value=1)

# %%
data.insert(loc=10, column='disp_i_bc', value=1)

# %%
data.insert(loc=11, column='vertical', value=1)

# %%
data.insert(loc=12, column='h_max', value=1)

# %%
data.insert(loc=13, column='h_min', value=1)

# %%
data.rename(columns={'temperature_C': 'temperature'}, inplace=True)

# %%
data.rename(columns={'pressure_MPa': 'pressure'}, inplace=True)

# %% [markdown]
# now check the file

# %%
data.head()
# Out:
#    Id   X    Y     Z  dX  dY  dZ   pressure  disp_k_bc  disp_j_bc  disp_i_bc  \
# 0   0  50  420 -1475  10  10  10  27.667349          1          1          1
# 1   1  60  420 -1475  10  10  10  27.666658          1          1          1
# 2   2  70  420 -1475  10  10  10  27.666128          1          1          1
# 3   3  80  420 -1475  10  10  10  27.665727          1          1          1
# 4   4  90  420 -1475  10  10  10  27.665387          1          1          1
#
#    vertical  h_max  h_min  sigma_h_max_MPa  sigma_h_min_MPa  Sigma_V_MPa  \
# 0         1      1      1        54.383797        47.417642    78.659853
# 1         1      1      1        54.381446        47.412370    78.656734
# 2         1      1      1        54.381283        47.408446    78.656918
# 3         1      1      1        54.383207        47.405856    78.660337
# 4         1      1      1        54.386726        47.404308    78.666232
#
#    temperature
# 0   226.074346
# 1   226.210827
# 2   226.350794
# 3   226.494008
# 4   226.640055

# %% [markdown]
# now sort so values are in correct order for em2ex

# %%
a = data.sort_values(["Z","Y","X"], ascending = [True, True, True])

# %%
a.head()
# Out:
#    Id   X    Y     Z  dX  dY  dZ   pressure  disp_k_bc  disp_j_bc  disp_i_bc  \
# 0   0  50  420 -1475  10  10  10  27.667349          1          1          1
# 1   1  60  420 -1475  10  10  10  27.666658          1          1          1
# 2   2  70  420 -1475  10  10  10  27.666128          1          1          1
# 3   3  80  420 -1475  10  10  10  27.665727          1          1          1
# 4   4  90  420 -1475  10  10  10  27.665387          1          1          1
#
#    vertical  h_max  h_min  sigma_h_max_MPa  sigma_h_min_MPa  Sigma_V_MPa  \
# 0         1      1      1        54.383797        47.417642    78.659853
# 1         1      1      1        54.381446        47.412370    78.656734
# 2         1      1      1        54.381283        47.408446    78.656918
# 3         1      1      1        54.383207        47.405856    78.660337
# 4         1      1      1        54.386726        47.404308    78.666232
#
#    temperature
# 0   226.074346
# 1   226.210827
# 2   226.350794
# 3   226.494008
# 4   226.640055

# %% [markdown]
# now we have all the needed columns in the dataframe.  Now can populate the new columns with data, and also fix the pressure and temperature

# %%
a['temperature'] =+ a['temperature'] + 273.15

# %%
a['pressure'] = a['pressure']* 1e6

# %%
a['disp_k_bc'] = (a['Sigma_V_MPa'] * -1e6)

# %%
a['disp_j_bc'] = (a['sigma_h_max_MPa'] * -1e6)

# %%
a['disp_i_bc'] = (a['sigma_h_min_MPa'] * -1e6)

# %% [markdown]
# to get IC for effective stress, must convert total to negtive and Pa, the add pressure.  Note that alpha (0.6) was already factored into the calculation of total stress, so we don't need to worry about it converting back into MOOSE conventions

# %%
a['vertical'] = (a['Sigma_V_MPa'] * -1e6) + (a['pressure'])

# %%
a['h_max'] = (a['sigma_h_max_MPa'] * -1e6) + (a['pressure'])

# %%
a['h_min'] = (a['sigma_h_min_MPa'] * -1e6) + (a['pressure'])

# %%
a.head()
# Out:
#    Id   X    Y     Z  dX  dY  dZ    pressure   disp_k_bc   disp_j_bc  \
# 0   0  50  420 -1475  10  10  10  27667348.9 -78659853.2 -54383797.3
# 1   1  60  420 -1475  10  10  10  27666657.9 -78656733.8 -54381446.3
# 2   2  70  420 -1475  10  10  10  27666128.4 -78656918.4 -54381283.4
# 3   3  80  420 -1475  10  10  10  27665726.5 -78660336.9 -54383207.2
# 4   4  90  420 -1475  10  10  10  27665386.7 -78666231.6 -54386726.3
#
#     disp_i_bc    vertical       h_max       h_min  sigma_h_max_MPa  \
# 0 -47417642.2 -50992504.3 -26716448.4 -19750293.3        54.383797
# 1 -47412369.6 -50990075.9 -26714788.4 -19745711.7        54.381446
# 2 -47408446.2 -50990790.0 -26715155.0 -19742317.8        54.381283
# 3 -47405856.2 -50994610.4 -26717480.7 -19740129.7        54.383207
# 4 -47404308.1 -51000844.9 -26721339.6 -19738921.4        54.386726
#
#    sigma_h_min_MPa  Sigma_V_MPa  temperature
# 0        47.417642    78.659853   499.224346
# 1        47.412370    78.656734   499.360827
# 2        47.408446    78.656918   499.500794
# 3        47.405856    78.660337   499.644008
# 4        47.404308    78.666232   499.790055

# %% [markdown]
# now we can delete some columns

# %%
del a['sigma_h_max_MPa']

# %%
del a['sigma_h_min_MPa']

# %%
del a['Sigma_V_MPa']

# %% [markdown]
# and now the dataframe should be ready for em2ex

# %%
a.head()
# Out:
#    Id   X    Y     Z  dX  dY  dZ    pressure   disp_k_bc   disp_j_bc  \
# 0   0  50  420 -1475  10  10  10  27667348.9 -78659853.2 -54383797.3
# 1   1  60  420 -1475  10  10  10  27666657.9 -78656733.8 -54381446.3
# 2   2  70  420 -1475  10  10  10  27666128.4 -78656918.4 -54381283.4
# 3   3  80  420 -1475  10  10  10  27665726.5 -78660336.9 -54383207.2
# 4   4  90  420 -1475  10  10  10  27665386.7 -78666231.6 -54386726.3
#
#     disp_i_bc    vertical       h_max       h_min  temperature
# 0 -47417642.2 -50992504.3 -26716448.4 -19750293.3   499.224346
# 1 -47412369.6 -50990075.9 -26714788.4 -19745711.7   499.360827
# 2 -47408446.2 -50990790.0 -26715155.0 -19742317.8   499.500794
# 3 -47405856.2 -50994610.4 -26717480.7 -19740129.7   499.644008
# 4 -47404308.1 -51000844.9 -26721339.6 -19738921.4   499.790055

# %% [markdown]
# now can write the data to a CSV file.

# %%
a.to_csv("processed_local_large_well_3_1b_node.csv", encoding='utf-8', index=False)

# %%
a.describe().to_csv("processed_local_large_well_3_1b_node_Summary.csv")

# %% [markdown]
# now need to read into leapfrog and verify all the mpaaings
